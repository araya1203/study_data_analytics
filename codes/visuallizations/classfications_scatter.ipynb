# %%
class1_x_value = [0,1,2,3,4]
class1_y_value = [1,3,5,7,9]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=class1_x_value, y=class1_y_value)

# %%
class3_x_value = [1.5, 2.5, 3.5, 4.5, 5.5]
class3_y_value = [3.5, 5.5, 7.5, 9.5, 11.5]

# %% [markdown]
# ## 하나 plot 표시

# %% [markdown]
# ### title, label, legend(제목, 레이블, 범례)

# %%
# 두 클래스 변수를 한 plot에 표현
plt.scatter(x=class1_x_value, y=class1_y_value, label='Class One')
plt.scatter(x=class2_x_value, y=class2_y_value, label='Class Two')
plt.title('Classfications Plot')
plt.xlabel('X  Axis') #plt.xlabel('x 축')
plt.ylabel('Y Axis')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # 두 클래스 변수를 한 plot에 표현
#       2 plt.scatter(x=class1_x_value, y=class1_y_value, label='Class One')
# ----> 3 plt.scatter(x=class2_x_value, y=class2_y_value, label='Class Two')
#       4 plt.title('Classfications Plot')
#       5 plt.xlabel('X  Axis') #plt.xlabel('x 축')
#
# NameError: name 'class2_x_value' is not defined

# %%
class3_x_value = [2,3,5,0,5,1,8]
class3_y_value = [5,6,1,-1,0,3,5]

# %%
plt.plot(class3_x_value, class3_y_value, 'go--')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
