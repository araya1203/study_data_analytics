# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font',family='Malgun Gothic')

df_TOCC = pd.read_csv('../../datasets/TypeOfContractChannel.csv')
df_TOCC
# Out:
#              id type_of_contract type_of_contract2 channel    datetime  Term  \
# 0      66758234               렌탈            Normal  서비스 방문  2019-10-20    60
# 1      66755948               렌탈  Extension_Rental  서비스 방문  2019-10-20    60
# 2      66756657               렌탈            Normal  홈쇼핑/방송  2019-10-20    60
# 3      66423450              멤버십               TAS   렌탈재계약  2019-10-20    12
# 4      66423204              멤버십               TAS   렌탈재계약  2019-10-20    12
# ...         ...              ...               ...     ...         ...   ...
# 51299  66579515              NaN         Promotion   R관리방판  2020-02-03    60
# 51300  66799558               렌탈            Normal    영업방판  2020-02-03    60
# 51301  66799197               렌탈         Promotion  홈쇼핑/방송  2020-02-03    39
# 51302  66792778              NaN            Normal    렌탈총판  2020-02-03    60
# 51303  66799607               렌탈            Normal    하이마트  2020-02-03    60
#
# ...

# %% [markdown]
# 귀무가설: 계약유형에 따라 해약여부가 달라지지 않는다.
# 대립가설: 계약유형에 따라
#
# #분석 결론
# - 통계 결론 :
# - 사실 결론 :

# %%
df_TOCC[['type_of_contract', 'cancellation']].describe()
# Out:
#        type_of_contract cancellation
# count             51300        51279
# unique                2            2
# top                  렌탈           정상
# freq              46481        50372

# %%
df_TOCC.category = df_TOCC[['type_of_contract', 'cancellation']]
# Out:
# C:\Users\04-02\AppData\Local\Temp\ipykernel_6636\939503705.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_TOCC.category = df_TOCC[['type_of_contract', 'cancellation']]

# %%
df_TOCC_category_pivot = pd.pivot_table(data=TOCC, index='type_of_contract' , columns='cancellation', aggfunc=len)
df_TOCC_category_pivot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd.pivot_table(data=TOCC, index='type_of_contract' , columns='cancellation', aggfunc=len)
#
# NameError: name 'TOCC' is not defined

# %%
import scipy
scipy.__version__
import scipy.stats as stats

# %%
stats.chi2_contingency(observed=df_TOCC_category_pivot, correction=True )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 stats.chi2_contingency(observed=df_TOCC_category_pivot, correction=True )
#
# NameError: name 'df_TOCC_category_pivot' is not defined
